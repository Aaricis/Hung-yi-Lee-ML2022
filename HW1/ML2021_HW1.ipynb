# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaricis/Hung-yi-Lee-ML2021/blob/main/ML2021_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Homework 1: COVID-19 Cases Prediction (Regression)**

# %% [markdown]
# # **Result**
#
# scores (pass strong baseline):
# ![image.png](data:image/png;base64,...)
#
# strong baseline:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **基于medium baseline的分析与改善**
#
# **1.修改助教Sample Code中的两个错误**
# - hw1 ppt介绍的损失函数是RMSE，代码实际使用MSE（但是改成RMSE其实没什么用）。
# - 数据归一化方式有误。对于不同的dataset，原Code使用各自的mean和std作归一。正确的做法是**使用相同的归一化参数**：
#   - 在对训练集进行归一化时，通常会计算一些参数（如均值、标准差或最大值/最小值）。在对测试集进行归一化时，必须使用这些相同的参数，而不是重新计算测试集的参数。
#
# **2.Feature Selection**
# - hw1跟平常见到的深度学习任务不太一样，有点像传统的机器学习任务，特征选择对结果影响很大。
# - 选择相关性较大的15个feature作为输入数据。
#
# **3.损失函数**
# - 增加L2正则项
#
# **4.网络结构**
# - 这个任务较简单，增加网络的复杂度会造成overfitting。
#
# **总结：**
#
# hw1与通常意义上的深度学习任务不同，Feature Selection起到很大作用，而不是调整网络结构。hw1更像是传统机器学习向深度学习的一个过渡。

# %% [markdown]
# # **Download Data**

# %%
tr_path = 'covid.train.csv'  # path to training data
tt_path = 'covid.test.csv'   # path to testing data

# !gdown --id '19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF' --output covid.train.csv
# !gdown --id '1CE240jLm2npU-tdz81-oVKEF3T2yfT1O' --output covid.test.csv
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=19CCyCgJrUxtvgZF53vnctJiOJ23T5mqF
# To: /content/covid.train.csv
# 100% 2.00M/2.00M [00:00<00:00, 90.1MB/s]
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1CE240jLm2npU-tdz81-oVKEF3T2yfT1O
# To: /content/covid.test.csv
# 100% 651k/651k [00:00<00:00, 105MB/s]

# %% [markdown]
# # **Import Some Packages**

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import numpy as np
import csv
import os
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


myseed = 42069
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# # **Data Analysis and Some Utilities**

# %%
train_data = pd.read_csv(tr_path)
train_data = train_data.drop(["id"], axis=1)
train_data.corr()
# Out:
#                             AL        AK        AZ        AR        CA  \
# AL                    1.000000 -0.025446 -0.025446 -0.025446 -0.025446
# AK                   -0.025446  1.000000 -0.025446 -0.025446 -0.025446
# AZ                   -0.025446 -0.025446  1.000000 -0.025446 -0.025446
# AR                   -0.025446 -0.025446 -0.025446  1.000000 -0.025446
# CA                   -0.025446 -0.025446 -0.025446 -0.025446  1.000000
# ...                        ...       ...       ...       ...       ...
# depressed.2          -0.035570  0.059403 -0.052381  0.218993 -0.007374
# felt_isolated.2      -0.170177  0.153638 -0.059705 -0.021997  0.058020
# worried_become_ill.2 -0.273551 -0.179413 -0.206808 -0.127898 -0.093832
# worried_finances.2   -0.047698 -0.098627 -0.157999  0.035605 -0.079045
# tested_positive.2     0.063479 -0.152682 -0.162097  0.030706 -0.208291
#
#                             CO        CT        FL        GA        ID  ...  \
# AL                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# AK                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# AZ                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# AR                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# CA                   -0.025446 -0.025446 -0.025446 -0.025446 -0.025446  ...
# ...                        ...       ...       ...       ...       ...  ...
# depressed.2           0.071091 -0.159754 -0.201005 -0.129952  0.037010  ...
# felt_isolated.2       0.020721 -0.172719 -0.195154 -0.179562 -0.032974  ...
# worried_become_ill.2 -0.120136  0.038770 -0.168653 -0.203301 -0.276828  ...
# worried_finances.2   -0.123659 -0.092067 -0.065390 -0.077847 -0.188089  ...
# tested_positive.2    -0.131460 -0.227023 -0.120834 -0.051948  0.175365  ...
#
#                       restaurant.2  spent_time.2  large_event.2  \
# AL                        0.210928      0.202805       0.279239
# AK                       -0.013452      0.051009       0.029212
# AZ                        0.177914      0.108104       0.098514
# AR                        0.112250      0.146078       0.187179
# CA                        0.027648      0.016425      -0.046107
# ...                            ...           ...            ...
# depressed.2              -0.067040      0.118125       0.066021
# felt_isolated.2          -0.641984     -0.507902      -0.554675
# worried_become_ill.2     -0.831868     -0.870630      -0.875487
# worried_finances.2       -0.435929     -0.524228      -0.380926
# tested_positive.2        -0.160181     -0.258956      -0.063709
#
#                       public_transit.2  anxious.2  depressed.2  \
# AL                           -0.073966  -0.153556    -0.035570
# AK                            0.194813   0.017483     0.059403
# AZ                            0.087006  -0.136689    -0.052381
# AR                           -0.117037   0.077963     0.218993
# CA                            0.104119  -0.018843    -0.007374
# ...                                ...        ...          ...
# depressed.2                  -0.164079   0.594797     1.000000
# felt_isolated.2               0.009571   0.525171     0.610310
# worried_become_ill.2         -0.047068   0.251509    -0.051246
# worried_finances.2           -0.142098   0.184126     0.026621
# tested_positive.2            -0.450436   0.152903     0.029578
#
#                       felt_isolated.2  worried_become_ill.2  \
# AL                          -0.170177             -0.273551
# AK                           0.153638             -0.179413
# AZ                          -0.059705             -0.206808
# AR                          -0.021997             -0.127898
# CA                           0.058020             -0.093832
# ...                               ...                   ...
# depressed.2                  0.610310             -0.051246
# felt_isolated.2              1.000000              0.407931
# worried_become_ill.2         0.407931              1.000000
# worried_finances.2           0.132465              0.495890
# tested_positive.2            0.081174              0.267610
#
#                       worried_finances.2  tested_positive.2
# AL                             -0.047698           0.063479
# AK                             -0.098627          -0.152682
# AZ                             -0.157999          -0.162097
# AR                              0.035605           0.030706
# CA                             -0.079045          -0.208291
# ...                                  ...                ...
# depressed.2                     0.026621           0.029578
# felt_isolated.2                 0.132465           0.081174
# worried_become_ill.2            0.495890           0.267610
# worried_finances.2              1.000000           0.485843
# tested_positive.2               0.485843           1.000000
#
# [94 rows x 94 columns]

# %%
feats = []
for idx, data in enumerate(train_data.corr()["tested_positive.2"].abs()):
  if data > 0.48 and idx != 93:
    feats.append(idx)

print(feats)
# Out:
# [40, 41, 42, 43, 57, 58, 59, 60, 61, 74, 75, 76, 77, 78, 79, 92]

# %%
with open("covid.train.csv", "r") as fp:
    train_data = list(csv.reader(fp))
    train_data = np.array(train_data[1:])[:, 1:-1].astype(float)

mean = torch.FloatTensor(train_data[:, feats]).mean(dim=0, keepdim=True)
std = torch.FloatTensor(train_data[:, feats]).std(dim=0, keepdim=True)

# %%
mean, std
# Out:
# (tensor([[ 0.9916,  1.0161, 29.4425, 24.3231, 16.3009,  0.9946,  1.0191, 29.5293,
#           24.4029, 44.5441, 16.3667,  0.9980,  1.0225, 29.6108, 24.4779, 44.5684]]),
#  tensor([[0.4203, 0.4236, 9.0937, 8.4468, 7.6378, 0.4201, 0.4235, 9.0829, 8.4431,
#           5.2488, 7.6275, 0.4202, 0.4237, 9.0705, 8.4370, 5.2320]]))

# %%
def get_device():
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()


def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('ground truth value')
    plt.ylabel('predicted value')
    plt.title('Ground Truth v.s. Prediction')
    plt.show()

# %% [markdown]
# # **Dataset and DataLoader**

# %%
class COVID19Dataset(Dataset):
    def __init__(self, path, mode='train', target_only=False):
        self.mode = mode

        with open(path, 'r') as fp:
            data = list(csv.reader(fp))
            data = np.array(data[1:])[:, 1:].astype(float)

        if mode == 'test':
          data = data[:, feats]
          self.data = torch.FloatTensor(data)

        else:
          target = data[:, -1]
          data = data[:, feats]

          if mode == 'train':
            indices = [i for i in range(len(data)) if i % 10 != 0]
          elif mode == 'dev':
            indices = [i for i in range(len(data)) if i % 10 == 0]

          self.data = torch.FloatTensor(data[indices])
          self.target = torch.FloatTensor(target[indices])


        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

        self.data = (self.data - mean) / std

    def __getitem__(self, index):

        if self.mode in ['train', 'dev']:

            return self.data[index], self.target[index]
        else:

            return self.data[index]

    def __len__(self):

        return len(self.data)

# %%
def prep_dataloader(path, mode, batch_size, n_jobs=0, target_only=False):
    dataset = COVID19Dataset(path, mode=mode, target_only=target_only)
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)
    return dataloader

# %% [markdown]
# # **Deep Neural Network**

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(input_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):
      loss = self.criterion(pred, target)
      l2 = 0
      for i in self.parameters():
        l2 += torch.sum(pow(i, 2))

      return loss + 0.002 * l2, loss

# %% [markdown]
# # **Train/Dev/Test**

# %%
def train(tr_set, dv_set, model, config, device):

    n_epochs = config['n_epochs']

    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()
        for x, y in tr_set:
            optimizer.zero_grad()
            x, y = x.to(device), y.to(device)
            pred = model(x)
            l2_loss, mse_loss = model.cal_loss(pred, y)
            l2_loss.backward()
            optimizer.step()
            loss_record['train'].append(mse_loss.detach().cpu().item())

        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %%
def dev(dv_set, model, device):
    model.eval()
    total_loss = 0
    for x, y in dv_set:
        x, y = x.to(device), y.to(device)
        with torch.no_grad():
            pred = model(x)
            _, mse_loss = model.cal_loss(pred, y)
        total_loss += mse_loss.detach().cpu().item() * len(x)
    total_loss = total_loss / len(dv_set.dataset)
    return total_loss

# %%
def test(tt_set, model, device):
    model.eval()
    preds = []
    for x in tt_set:
        x = x.to(device)
        with torch.no_grad():
            pred = model(x)
            preds.append(pred.detach().cpu())
    preds = torch.cat(preds, dim=0).numpy()
    return preds

# %% [markdown]
# # **Setup Hyper-parameters**

# %%
device = get_device()
os.makedirs('models', exist_ok=True)
target_only = False

config = {
    'n_epochs': 3000,
    'batch_size': 128,
    'optimizer': 'SGD',
    'optim_hparas': {
        'lr': 0.0001,
        'momentum': 0.9
    },
    'early_stop': 200,
    'save_path': 'models/model.pth'
}

# %% [markdown]
# # **Load data and model**

# %%
tr_set = prep_dataloader(tr_path, 'train', config['batch_size'], target_only=target_only)
dv_set = prep_dataloader(tr_path, 'dev', config['batch_size'], target_only=target_only)
tt_set = prep_dataloader(tt_path, 'test', config['batch_size'], target_only=target_only)
# Out:
# Finished reading the train set of COVID19 Dataset (2430 samples found, each dim = 16)
# Finished reading the dev set of COVID19 Dataset (270 samples found, each dim = 16)
# Finished reading the test set of COVID19 Dataset (893 samples found, each dim = 16)

# %%
model = NeuralNet(tr_set.dataset.dim).to(device)

# %% [markdown]
# # **Start Training**

# %%
model_loss, model_loss_record = train(tr_set, dv_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 279.0623)
# Saving model (epoch =    2, loss = 154.1063)
# Saving model (epoch =    3, loss = 81.4683)
# Saving model (epoch =    4, loss = 66.0441)
# Saving model (epoch =    5, loss = 55.0105)
# Saving model (epoch =    6, loss = 45.6889)
# Saving model (epoch =    7, loss = 37.6201)
# Saving model (epoch =    8, loss = 29.5949)
# Saving model (epoch =    9, loss = 21.9064)
# Saving model (epoch =   10, loss = 14.5768)
# Saving model (epoch =   11, loss = 9.2944)
# Saving model (epoch =   12, loss = 6.3040)
# Saving model (epoch =   13, loss = 4.6133)
# Saving model (epoch =   14, loss = 3.7288)
# Saving model (epoch =   15, loss = 3.1454)
# Saving model (epoch =   16, loss = 2.6874)
# Saving model (epoch =   17, loss = 2.3318)
# Saving model (epoch =   18, loss = 2.0698)
# Saving model (epoch =   19, loss = 1.8800)
# Saving model (epoch =   20, loss = 1.7483)
# Saving model (epoch =   21, loss = 1.6439)
# Saving model (epoch =   22, loss = 1.5698)
# Saving model (epoch =   23, loss = 1.4976)
# Saving model (epoch =   24, loss = 1.4428)
# Saving model (epoch =   25, loss = 1.3942)
# Saving model (epoch =   26, loss = 1.3545)
# Saving model (epoch =   27, loss = 1.3233)
# Saving model (epoch =   28, loss = 1.2988)
# Saving model (epoch =   29, loss = 1.2729)
# Saving model (epoch =   30, loss = 1.2553)
# Saving model (epoch =   31, loss = 1.2311)
# Saving model (epoch =   32, loss = 1.2151)
# Saving model (epoch =   33, loss = 1.1992)
# Saving model (epoch =   34, loss = 1.1855)
# Saving model (epoch =   35, loss = 1.1755)
# Saving model (epoch =   36, loss = 1.1639)
# Saving model (epoch =   37, loss = 1.1545)
# Saving model (epoch =   38, loss = 1.1462)
# Saving model (epoch =   39, loss = 1.1393)
# Saving model (epoch =   40, loss = 1.1360)
# Saving model (epoch =   41, loss = 1.1281)
# Saving model (epoch =   42, loss = 1.1255)
# Saving model (epoch =   43, loss = 1.1169)
# Saving model (epoch =   44, loss = 1.1136)
# Saving model (epoch =   45, loss = 1.1089)
# Saving model (epoch =   46, loss = 1.1048)
# Saving model (epoch =   47, loss = 1.1036)
# Saving model (epoch =   48, loss = 1.0991)
# Saving model (epoch =   50, loss = 1.0925)
# Saving model (epoch =   52, loss = 1.0881)
# Saving model (epoch =   53, loss = 1.0842)
# Saving model (epoch =   54, loss = 1.0807)
# Saving model (epoch =   55, loss = 1.0791)
# Saving model (epoch =   56, loss = 1.0758)
# Saving model (epoch =   57, loss = 1.0751)
# Saving model (epoch =   58, loss = 1.0710)
# Saving model (epoch =   59, loss = 1.0697)
# Saving model (epoch =   60, loss = 1.0685)
# Saving model (epoch =   61, loss = 1.0639)
# Saving model (epoch =   62, loss = 1.0613)
# Saving model (epoch =   64, loss = 1.0600)
# Saving model (epoch =   65, loss = 1.0589)
# Saving model (epoch =   66, loss = 1.0565)
# Saving model (epoch =   67, loss = 1.0544)
# Saving model (epoch =   68, loss = 1.0505)
# Saving model (epoch =   69, loss = 1.0488)
# Saving model (epoch =   70, loss = 1.0452)
# Saving model (epoch =   72, loss = 1.0424)
# Saving model (epoch =   73, loss = 1.0414)
# Saving model (epoch =   74, loss = 1.0387)
# Saving model (epoch =   76, loss = 1.0354)
# Saving model (epoch =   78, loss = 1.0326)
# Saving model (epoch =   79, loss = 1.0306)
# Saving model (epoch =   80, loss = 1.0287)
# Saving model (epoch =   82, loss = 1.0270)
# Saving model (epoch =   83, loss = 1.0241)
# Saving model (epoch =   84, loss = 1.0222)
# Saving model (epoch =   86, loss = 1.0199)
# Saving model (epoch =   87, loss = 1.0194)
# Saving model (epoch =   88, loss = 1.0164)
# Saving model (epoch =   89, loss = 1.0154)
# Saving model (epoch =   90, loss = 1.0148)
# Saving model (epoch =   91, loss = 1.0120)
# Saving model (epoch =   93, loss = 1.0110)
# Saving model (epoch =   95, loss = 1.0064)
# Saving model (epoch =   96, loss = 1.0057)
# Saving model (epoch =   97, loss = 1.0032)
# Saving model (epoch =   99, loss = 1.0017)
# Saving model (epoch =  101, loss = 0.9984)
# Saving model (epoch =  103, loss = 0.9968)
# Saving model (epoch =  104, loss = 0.9961)
# Saving model (epoch =  105, loss = 0.9943)
# Saving model (epoch =  107, loss = 0.9917)
# Saving model (epoch =  109, loss = 0.9901)
# Saving model (epoch =  110, loss = 0.9890)
# Saving model (epoch =  111, loss = 0.9866)
# Saving model (epoch =  113, loss = 0.9865)
# Saving model (epoch =  114, loss = 0.9854)
# Saving model (epoch =  115, loss = 0.9830)
# Saving model (epoch =  116, loss = 0.9825)
# Saving model (epoch =  117, loss = 0.9815)
# Saving model (epoch =  119, loss = 0.9788)
# Saving model (epoch =  120, loss = 0.9779)
# Saving model (epoch =  121, loss = 0.9764)
# Saving model (epoch =  124, loss = 0.9762)
# Saving model (epoch =  126, loss = 0.9715)
# Saving model (epoch =  128, loss = 0.9713)
# Saving model (epoch =  130, loss = 0.9694)
# Saving model (epoch =  131, loss = 0.9669)
# Saving model (epoch =  133, loss = 0.9665)
# Saving model (epoch =  134, loss = 0.9648)
# Saving model (epoch =  135, loss = 0.9639)
# Saving model (epoch =  137, loss = 0.9621)
# Saving model (epoch =  139, loss = 0.9612)
# Saving model (epoch =  140, loss = 0.9600)
# Saving model (epoch =  142, loss = 0.9574)
# Saving model (epoch =  143, loss = 0.9568)
# Saving model (epoch =  146, loss = 0.9551)
# Saving model (epoch =  147, loss = 0.9541)
# Saving model (epoch =  149, loss = 0.9520)
# Saving model (epoch =  151, loss = 0.9505)
# Saving model (epoch =  153, loss = 0.9487)
# Saving model (epoch =  156, loss = 0.9470)
# Saving model (epoch =  158, loss = 0.9455)
# Saving model (epoch =  161, loss = 0.9441)
# Saving model (epoch =  162, loss = 0.9432)
# Saving model (epoch =  164, loss = 0.9424)
# Saving model (epoch =  166, loss = 0.9395)
# Saving model (epoch =  170, loss = 0.9395)
# Saving model (epoch =  171, loss = 0.9382)
# Saving model (epoch =  174, loss = 0.9366)
# Saving model (epoch =  175, loss = 0.9357)
# Saving model (epoch =  177, loss = 0.9354)
# Saving model (epoch =  179, loss = 0.9345)
# Saving model (epoch =  181, loss = 0.9318)
# Saving model (epoch =  183, loss = 0.9312)
# Saving model (epoch =  185, loss = 0.9297)
# Saving model (epoch =  188, loss = 0.9289)
# Saving model (epoch =  189, loss = 0.9280)
# Saving model (epoch =  191, loss = 0.9277)
# Saving model (epoch =  192, loss = 0.9269)
# Saving model (epoch =  194, loss = 0.9253)
# Saving model (epoch =  196, loss = 0.9242)
# Saving model (epoch =  198, loss = 0.9229)
# Saving model (epoch =  199, loss = 0.9227)
# Saving model (epoch =  205, loss = 0.9217)
# Saving model (epoch =  206, loss = 0.9211)
# Saving model (epoch =  208, loss = 0.9203)
# Saving model (epoch =  211, loss = 0.9180)
# Saving model (epoch =  213, loss = 0.9165)
# Saving model (epoch =  215, loss = 0.9156)
# Saving model (epoch =  220, loss = 0.9155)
# Saving model (epoch =  222, loss = 0.9142)
# Saving model (epoch =  224, loss = 0.9120)
# Saving model (epoch =  226, loss = 0.9119)
# Saving model (epoch =  228, loss = 0.9109)
# Saving model (epoch =  231, loss = 0.9094)
# Saving model (epoch =  234, loss = 0.9088)
# Saving model (epoch =  237, loss = 0.9078)
# Saving model (epoch =  241, loss = 0.9075)
# Saving model (epoch =  243, loss = 0.9071)
# Saving model (epoch =  245, loss = 0.9054)
# Saving model (epoch =  247, loss = 0.9041)
# Saving model (epoch =  253, loss = 0.9035)
# Saving model (epoch =  254, loss = 0.9023)
# Saving model (epoch =  256, loss = 0.9013)
# Saving model (epoch =  261, loss = 0.9008)
# Saving model (epoch =  263, loss = 0.8997)
# Saving model (epoch =  267, loss = 0.8988)
# Saving model (epoch =  271, loss = 0.8985)
# Saving model (epoch =  272, loss = 0.8983)
# Saving model (epoch =  273, loss = 0.8983)
# Saving model (epoch =  277, loss = 0.8956)
# Saving model (epoch =  283, loss = 0.8953)
# Saving model (epoch =  285, loss = 0.8937)
# Saving model (epoch =  288, loss = 0.8932)
# Saving model (epoch =  291, loss = 0.8920)
# Saving model (epoch =  295, loss = 0.8913)
# Saving model (epoch =  300, loss = 0.8906)
# Saving model (epoch =  302, loss = 0.8896)
# Saving model (epoch =  304, loss = 0.8893)
# Saving model (epoch =  307, loss = 0.8893)
# Saving model (epoch =  313, loss = 0.8887)
# Saving model (epoch =  316, loss = 0.8878)
# Saving model (epoch =  318, loss = 0.8864)
# Saving model (epoch =  319, loss = 0.8856)
# Saving model (epoch =  324, loss = 0.8851)
# Saving model (epoch =  334, loss = 0.8848)
# Saving model (epoch =  335, loss = 0.8846)
# Saving model (epoch =  336, loss = 0.8840)
# Saving model (epoch =  343, loss = 0.8826)
# Saving model (epoch =  347, loss = 0.8820)
# Saving model (epoch =  352, loss = 0.8799)
# Saving model (epoch =  360, loss = 0.8792)
# Saving model (epoch =  369, loss = 0.8788)
# Saving model (epoch =  372, loss = 0.8786)
# Saving model (epoch =  373, loss = 0.8774)
# Saving model (epoch =  380, loss = 0.8764)
# Saving model (epoch =  383, loss = 0.8751)
# Saving model (epoch =  397, loss = 0.8743)
# Saving model (epoch =  401, loss = 0.8739)
# Saving model (epoch =  405, loss = 0.8726)
# Saving model (epoch =  412, loss = 0.8717)
# Saving model (epoch =  421, loss = 0.8716)
# Saving model (epoch =  429, loss = 0.8707)
# Saving model (epoch =  436, loss = 0.8700)
# Saving model (epoch =  439, loss = 0.8696)
# Saving model (epoch =  448, loss = 0.8694)
# Saving model (epoch =  449, loss = 0.8685)
# Saving model (epoch =  454, loss = 0.8679)
# Saving model (epoch =  471, loss = 0.8668)
# Saving model (epoch =  473, loss = 0.8665)
# Saving model (epoch =  478, loss = 0.8658)
# Saving model (epoch =  481, loss = 0.8654)
# Saving model (epoch =  498, loss = 0.8651)
# Saving model (epoch =  499, loss = 0.8646)
# Saving model (epoch =  506, loss = 0.8639)
# Saving model (epoch =  524, loss = 0.8638)
# Saving model (epoch =  528, loss = 0.8623)
# Saving model (epoch =  535, loss = 0.8618)
# Saving model (epoch =  560, loss = 0.8612)
# Saving model (epoch =  569, loss = 0.8609)
# Saving model (epoch =  581, loss = 0.8604)
# Saving model (epoch =  587, loss = 0.8598)
# Saving model (epoch =  592, loss = 0.8597)
# Saving model (epoch =  600, loss = 0.8597)
# Saving model (epoch =  609, loss = 0.8586)
# Saving model (epoch =  614, loss = 0.8585)
# Saving model (epoch =  631, loss = 0.8585)
# Saving model (epoch =  632, loss = 0.8583)
# Saving model (epoch =  647, loss = 0.8578)
# Saving model (epoch =  648, loss = 0.8575)
# Saving model (epoch =  651, loss = 0.8572)
# Saving model (epoch =  661, loss = 0.8564)
# Saving model (epoch =  691, loss = 0.8564)
# Saving model (epoch =  695, loss = 0.8558)
# Saving model (epoch =  703, loss = 0.8553)
# Saving model (epoch =  728, loss = 0.8542)
# Saving model (epoch =  757, loss = 0.8537)
# Saving model (epoch =  771, loss = 0.8536)
# Saving model (epoch =  797, loss = 0.8535)
# Saving model (epoch =  802, loss = 0.8527)
# Saving model (epoch =  814, loss = 0.8523)
# Saving model (epoch =  837, loss = 0.8522)
# Saving model (epoch =  858, loss = 0.8515)
# Saving model (epoch =  891, loss = 0.8510)
# Saving model (epoch =  917, loss = 0.8510)
# Saving model (epoch =  933, loss = 0.8506)
# Saving model (epoch =  941, loss = 0.8503)
# Saving model (epoch =  977, loss = 0.8496)
# Saving model (epoch = 1010, loss = 0.8495)
# Saving model (epoch = 1013, loss = 0.8490)
# Saving model (epoch = 1045, loss = 0.8490)
# Saving model (epoch = 1053, loss = 0.8490)
# Saving model (epoch = 1068, loss = 0.8490)
# Saving model (epoch = 1070, loss = 0.8488)
# Saving model (epoch = 1089, loss = 0.8484)
# Saving model (epoch = 1119, loss = 0.8478)
# Saving model (epoch = 1134, loss = 0.8475)
# Saving model (epoch = 1154, loss = 0.8474)
# Saving model (epoch = 1174, loss = 0.8466)
# Saving model (epoch = 1232, loss = 0.8466)
# Saving model (epoch = 1281, loss = 0.8464)
# Saving model (epoch = 1292, loss = 0.8463)
# Saving model (epoch = 1332, loss = 0.8456)
# Saving model (epoch = 1386, loss = 0.8453)
# Saving model (epoch = 1390, loss = 0.8453)
# Saving model (epoch = 1412, loss = 0.8453)
# Saving model (epoch = 1423, loss = 0.8453)
# Saving model (epoch = 1425, loss = 0.8450)
# Saving model (epoch = 1451, loss = 0.8448)
# Saving model (epoch = 1501, loss = 0.8447)
# Saving model (epoch = 1506, loss = 0.8444)
# Saving model (epoch = 1527, loss = 0.8444)
# Saving model (epoch = 1536, loss = 0.8440)
# Saving model (epoch = 1605, loss = 0.8439)
# Saving model (epoch = 1612, loss = 0.8437)
# Saving model (epoch = 1627, loss = 0.8435)
# Saving model (epoch = 1665, loss = 0.8433)
# Saving model (epoch = 1689, loss = 0.8433)
# Saving model (epoch = 1726, loss = 0.8430)
# Saving model (epoch = 1756, loss = 0.8421)
# Saving model (epoch = 1762, loss = 0.8418)
# Saving model (epoch = 1786, loss = 0.8417)
# Saving model (epoch = 1798, loss = 0.8416)
# Saving model (epoch = 1802, loss = 0.8412)
# Saving model (epoch = 1834, loss = 0.8411)
# Saving model (epoch = 1881, loss = 0.8409)
# Saving model (epoch = 1893, loss = 0.8408)
# Saving model (epoch = 1898, loss = 0.8408)
# Saving model (epoch = 1938, loss = 0.8403)
# Saving model (epoch = 2004, loss = 0.8399)
# Saving model (epoch = 2034, loss = 0.8396)
# Saving model (epoch = 2036, loss = 0.8395)
# Saving model (epoch = 2056, loss = 0.8389)
# Saving model (epoch = 2147, loss = 0.8387)
# Saving model (epoch = 2187, loss = 0.8385)
# Saving model (epoch = 2204, loss = 0.8384)
# Saving model (epoch = 2250, loss = 0.8382)
# Saving model (epoch = 2253, loss = 0.8377)
# Saving model (epoch = 2363, loss = 0.8373)
# Saving model (epoch = 2437, loss = 0.8368)
# Saving model (epoch = 2512, loss = 0.8368)
# Saving model (epoch = 2531, loss = 0.8363)
# Saving model (epoch = 2547, loss = 0.8361)
# Saving model (epoch = 2601, loss = 0.8361)
# Saving model (epoch = 2664, loss = 0.8353)
# Saving model (epoch = 2691, loss = 0.8352)
# Saving model (epoch = 2797, loss = 0.8349)
# Saving model (epoch = 2801, loss = 0.8347)
# Saving model (epoch = 2938, loss = 0.8345)
# Saving model (epoch = 2940, loss = 0.8341)
# Finished training after 3000 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(tr_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')
model.load_state_dict(ckpt)
plot_pred(dv_set, model, device)
# Out:
# <ipython-input-19-ff750adea3b1>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(config['save_path'], map_location='cpu')

# %% [markdown]
# # **Testing**

# %%
def save_pred(preds, file):
    ''' Save predictions to specified file '''
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(tt_set, model, device)
save_pred(preds, 'pred.csv')
# Out:
# Saving results to pred_shuffle.csv
